# %% [markdown]
# # Week 4 - 30/10/17
#
# (contd.)
#
# This week we're switching to jupyter notebooks, because figures were getting a bit much.

# %%
from hm.analysis.explicit_tripoint import epsilon, anaTP, epsChangeY

# %% [markdown]
# This is probing the effect of using $\tilde{m_b} = \tilde{m_j} + \tilde{m_k} − T_{ij} − T{ji}$

# %%
anaTP(0.05,0.2,0.01,0.02,20,1000, ib=True, tildeM=False, heatmap=False)
anaTP(0.05,0.2,0.01,0.02,20,1000, ib=True, tildeM=True, heatmap=False)
