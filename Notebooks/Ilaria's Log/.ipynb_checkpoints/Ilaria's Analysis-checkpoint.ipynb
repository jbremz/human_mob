# %% [markdown]
# # Week 4 (October 30)

# %% [markdown]
# Gonna do my analysis/plotting here instead of having this in the main script.
#
# First: **gravity**.
#
# Here I'm using a random distribution for the locations on a 1x1 square with a uniform population distribution of 1.
# The gravity law is in its power law form:
# $$ p_{ij} = k_i\frac{m_j}{r^\gamma}$$

# %%
from hm.analysis import random_tripoint as rt
from hm.pop_models.pop_random import random as pop_random
from hm.hm_models.gravity import gravity
from hm.hm_models.radiation import radiation
from hm.hm_models.opportunities import opportunities
from matplotlib import pyplot as plt

import importlib
importlib.reload(rt)

N = 100
alpha, beta = 1, 1
gamma = 0.2
p = pop_random(N)
g = gravity(p, alpha, beta, gamma, exp=True)

rt.target_dist_plot(p, g)
rt.neighbours_dist_plot(p, g)

# %%
r = radiation(p)
rt.target_dist_plot(p, r)
rt.neighbours_dist_plot(p, r)

# %%
o = opportunities(p, gamma)
rt.target_dist_plot(p, o)
rt.neighbours_dist_plot(p, o)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
