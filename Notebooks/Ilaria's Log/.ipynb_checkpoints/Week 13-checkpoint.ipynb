# %% [markdown]
# # WEEK 13 (22/01/18)

# %% [markdown]
# # Done
# * Rewrote eps_scale in object-oriented style
# *
#
# ### To Do
# * Give population all 1 to pull out mass dependencies and plot to see
# * Store DMs for a few cities
#
# ### Questions
# * <font color='green'>  </font>

# %% [markdown]
# ## 1. Uniform mass distribution

# %% [markdown]
# Since we now have too many variables that $\epsilon$ might depend on, let's try and simplify by using a uniform mass distribution ($m_i = 1  \forall i$). This way, we can pick out the mass dependencies by comparing the $\epsilon$ plots to what we did last week (see Notebook *Week 12*).

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from hm.analysis.scaling import eps_scale
from hm.analysis.scaling.plots import eps_distance
from matplotlib import pyplot as plt
import pandas

# %%
df = pandas.read_csv("/Users/Ilaria/Documents/Imperial/MSci_Project/Code/human_mob/data/LSOA populations and areas 2011 (merged).csv")
lon_df = df[df['Easting'] < 561966][df['Easting'] > 493024][df['Northing'] < 207218][df['Northing'] > 150912]
lon_df['TotPop2011'] = 1
lon_df
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#        Unnamed: 0       CODE                       Name  TotPop2011  \
# 15785       15785  E01023906               Watford 001C           1
# 15786       15786  E01023907               Watford 001D           1
# 15787       15787  E01023904               Watford 001A           1
# 15789       15789  E01023905               Watford 001B           1
# 15791       15791  E01023902               Watford 010D           1
# 15793       15793  E01023903               Watford 010E           1
# 15795       15795  E01023900               Watford 010B           1
# 15797       15797  E01023901               Watford 010C           1
# 15801       15801  E01023908       Welwyn Hatfield 015A           1
# 15802       15802  E01023909       Welwyn Hatfield 015B           1
# 15817       15817  E01015982              Thurrock 019A           1
# 15834       15834  E01023866               Watford 011D           1
# 15835       15835  E01023867               Watford 011E           1
# 15836       15836  E01023864               Watford 011B           1
# 15837       15837  E01023865               Watford 011C           1
# 15838       15838  E01023862               Watford 009D           1
# 15839       15839  E01023863               Watford 011A           1
# 15840       15840  E01023860               Watford 009B           1
# 15841       15841  E01023861               Watford 009C           1
# 15842       15842  E01023868               Watford 004A           1
# 15843       15843  E01023869               Watford 004B           1
# 15844       15844  E01021806         Epping Forest 009A           1
# 15846       15846  E01021807         Epping Forest 008A           1
# 15848       15848  E01021804         Epping Forest 010C           1
# 15851       15851  E01021805         Epping Forest 010D           1
# 15854       15854  E01021802         Epping Forest 004D           1
# 15856       15856  E01021803         Epping Forest 010B           1
# 15859       15859  E01021800         Epping Forest 003C           1
# 15867       15867  E01021808         Epping Forest 008B           1
# 15869       15869  E01021809         Epping Forest 008C           1
# ...           ...        ...                        ...         ...
# 29363       29363  E01024153              Dartford 010D           1
# 29364       29364  E01024150              Dartford 010A           1
# 29365       29365  E01024151              Dartford 010B           1
# 29366       29366  E01024158              Dartford 013B           1
# 29386       29386  E01030554           Mole Valley 004D           1
# 29395       29395  E01030656             Runnymede 004A           1
# 29396       29396  E01030652             Runnymede 006A           1
# 29406       29406  E01024135              Dartford 012C           1
# 29407       29407  E01024132              Dartford 012A           1
# 29418       29418  E01030992                Woking 010B           1
# 29423       29423  E01030373             Elmbridge 012C           1
# 29426       29426  E01030510           Mole Valley 004A           1
# 29431       29431  E01017834           South Bucks 005D           1
# 29450        1248        524   504805    156322  1.968468e+07
# 29464        1435        549   538810    153654  4.320455e+06
# 29466        1439        623   497140    202615  1.211140e+06
# 29480        1815        776   498578    192711  5.240496e+06
# 29483        1544        662   512028    164579  8.447921e+05
# 29498        1983        811   510849    167036  3.014513e+06
# 29513        1530        636   524101    159976  9.885940e+05
# 29521        1473        572   540379    151374  3.120907e+05
# 29527        1647        613   514813    160744  6.119256e+06
# 29530        1490        557   509814    153748  4.641295e+06
# 29531        1499        603   557574    164046  9.146092e+06
# 29533        1517        655   498385    157990  1.747248e+06
# 29542        1148        498   555782    169863  1.943271e+06
# 29558        1026        471   498098    158489  1.735363e+05
# 29561        1763        813   495699    197440  8.105503e+06
#
# [6061 rows x 9 columns]

# %%
d_max = [300, 500, 700, 1000, 1300]
gamma = 3.49
N = 20 # number of bins

# %%
levels = eps_scale.iterate(lon_df, d_max)
level_1 = levels[0]
level_2 = levels[1]
level_3 = levels[2]
level_4 = levels[3]
level_5 = levels[4]

# %% [markdown]
# ### 1.1 Level 1

# %%
eps_level_1 = eps_scale.epsilon(levels, 1, gamma)
# Out:
# /Users/Ilaria/Documents/Imperial/MSci_Project/Code/human_mob/hm/coarse_grain/coarse_matrix.py:49: RuntimeWarning: divide by zero encountered in true_divide
#   eps = (ODM2 - ODM1)/ODM2
# /Users/Ilaria/Documents/Imperial/MSci_Project/Code/human_mob/hm/coarse_grain/coarse_matrix.py:49: RuntimeWarning: invalid value encountered in true_divide
#   eps = (ODM2 - ODM1)/ODM2

# %%
DM = eps_scale.cluster_population(levels[1]).DM
eps_distance(abs(eps), DM, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-2cc93e096114> in <module>()
#       1 DM = eps_scale.cluster_population(levels[1]).DM
# ----> 2 eps_distance(abs(eps), DM, N)
#
# NameError: name 'eps_distance' is not defined

# %%
width = 7
height = 7
plt.figure(figsize=(width, height))
x = eps_scale.cluster_population(level_1).DM[100][1:] #distance of location 20 with all the others
y = eps_level_1[100][1:]
plt.ylim(-0.00025, 0.00025)
plt.scatter(x, y)
plt.show()

# %% [markdown]
# Something weird here, it looks exactly the same as before.
#
# Is it actually independent of masses? Or are we doing something wrong? Maybe we can have a look at the ODMs to get a better idea.

# %% [markdown]
# ### 1.2 Level 2

# %%
eps_level_2 = eps_scale.epsilon(levels, 2, gamma)
# Out:
# /Users/Ilaria/Documents/Imperial/MSci_Project/Code/human_mob/hm/coarse_grain/coarse_matrix.py:49: RuntimeWarning: divide by zero encountered in true_divide
#   eps = (ODM2 - ODM1)/ODM2
# /Users/Ilaria/Documents/Imperial/MSci_Project/Code/human_mob/hm/coarse_grain/coarse_matrix.py:49: RuntimeWarning: invalid value encountered in true_divide
#   eps = (ODM2 - ODM1)/ODM2

# %%
width = 7
height = 7
plt.figure(figsize=(width, height))
x = eps_scale.cluster_population(level_2).DM[100][1:] #distance of location 20 with all the others
y = eps_level_2[100][1:]
plt.ylim(0.001, 0.004)
plt.scatter(x, y)
plt.show()

# %% [markdown]
# Looks the same here, too. Let's have a look at the ODMs then.
