# %% [markdown]
# # Week 16 - 12/2/18
#
# **OBJECTIVES**

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## $\gamma_{opt}$ for different cities

# %%
import matplotlib.pyplot as plt
import pandas as pd
from hm.analysis.scaling.plots import *
from hm.analysis.scaling.pop_hierarchy import pop_hier
import scipy as sp
from hm.analysis.scaling.gamma_opt import optimise_eps, mean_eps
from hm.utils.utils import gamma_est

# %%
master_df = pd.read_csv("../../data/LSOA populations and areas 2011 (merged).csv")

# %% [markdown]
# The one below is for London.

# %%
df = master_df[master_df['Easting'] < 561966][master_df['Easting'] > 493024][master_df['Northing'] < 207218][master_df['Northing'] > 150912]

# %%
small_df = df[df['Easting'] < 527530][df['Easting'] > 493171][df['Northing'] < 179073.5][df['Northing'] > 150941]

# %% [markdown]
# ## Bristol & Bath

# %%
bris_bath_df = master_df[(master_df['Easting'] < 384235) & (master_df['Easting'] > 340217)][(master_df['Northing'] < 190238) & (master_df['Northing'] > 155072)]

# %%
len(bris_bath_df)
# Out:
# 622

# %%
d_maxs = np.linspace(300, 1500, 10)
h = pop_hier(bris_bath_df, d_maxs)
gamma_0 = gamma_est(np.mean(h.levels[0].pop.locArea))

# %%
gamma_0
# Out:
# 1.5219882014384136

# %%
gamma_opts = []
for l in range(1, len(h.levels)+1):
    print('Level ', l)
    gamma_opts.append(optimise_eps(h, l, gamma_0).x)

# %%
gamma_opts
# Out:
# [1.5256357128927311,
#  1.5396172070471004,
#  1.5681154106066051,
#  1.5946772306606201,
#  1.6143019660850773,
#  1.6359766496564256,
#  1.651225692388721,
#  1.6656841842462271,
#  1.6784706506525313,
#  1.6882263940588866]

# %%
gamma_dmax(d_maxs, gamma_opts)

# %%
gamma_d(h, gamma_opts)

# %%
gamma_S(h, gamma_0, gamma_opts)

# %% [markdown]
# ## Small Birmingham

# %%
small_bir_df = master_df[(master_df['Easting'] < 418638) & (master_df['Easting'] > 396129)][(master_df['Northing'] < 298220) & (master_df['Northing'] > 276158)]

# %%
len(small_bir_df)
# Out:
# 991

# %% [markdown]
# This is quite small, perhaps we shouldn't trust it.

# %%
d_maxs = np.linspace(300, 1500, 10)
h = pop_hier(small_bir_df, d_maxs)
gamma_0 = gamma_est(np.mean(h.levels[0].pop.locArea))

# %%
gamma_opts = []
for l in range(1, len(h.levels)+1):
    print('Level ', l)
    gamma_opts.append(optimise_eps(h, l, gamma_0).x)

# %%
gamma_opts
# Out:
# [1.3052272719530382,
#  1.3155419644040702,
#  1.3326716630536424,
#  1.353471659037667,
#  1.3720645139272232,
#  1.38780310827947,
#  1.4098369916430964,
#  1.4260835479183911,
#  1.4419252782062679,
#  1.4564189083358599]

# %%
gamma_dmax(d_maxs, gamma_opts)

# %%
gamma_d(h, gamma_opts)

# %%
gamma_S(h, gamma_0, gamma_opts)

# %% [markdown]
# ## Birmingham
#
# The whole of Birmingham this time.

# %%
bir_df = master_df[(master_df['Easting'] < 447384) & (master_df['Easting'] > 375647)][(master_df['Northing'] < 314728) & (master_df['Northing'] > 261315)]

# %%
len(bir_df)
# Out:
# 2415

# %%
d_maxs = np.linspace(300, 1500, 10)
h = pop_hier(bir_df, d_maxs)
gamma_0 = gamma_est(np.mean(h.levels[0].pop.locArea))

# %%
gamma_opts = []
for l in range(1, len(h.levels)+1):
    print('Level ', l)
    gamma_opts.append(optimise_eps(h, l, gamma_0).x)

# %%
gamma_opts
# Out:
# [1.4719578402107143,
#  1.4823291752423873,
#  1.4985529947472533,
#  1.5153393622807743,
#  1.5303441119374954,
#  1.5446313085592993,
#  1.5589964695463479,
#  1.5712366573289138,
#  1.5784132512743259,
#  1.5873630094660114]

# %%
gamma_dmax(d_maxs, gamma_opts)

# %%
gamma_d(h, gamma_opts)

# %%
gamma_S(h, gamma_0, gamma_opts)

# %% [markdown]
# These all look very good.
